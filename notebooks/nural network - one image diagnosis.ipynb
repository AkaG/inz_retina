# %%
from neural_network.nn_manager.TrainManager import TrainManager
from neural_network.store.DBNNSave import DBNNSave
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Reshape, Input, Conv2D, BatchNormalization
from keras.layers.convolutional import Convolution1D, Convolution2D, MaxPooling2D
import keras.backend as K
from random import shuffle
import h5py
import numpy as np
import tensorflow as tf

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)
np.random.seed(7)
# Out:
# Using TensorFlow backend.

# %%
class retinaNN(TrainManager):
    def __init__(self):
        self.path_to_data = './size_100o_one_img.hdf5'
        self.prepare_data(self.path_to_data)
        self.batch_size = 64
        self.epochs = 20
        self.example_images = []
        super(retinaNN, self).__init__()
        
    def prepare_data(self, path):
        hdf5_file = h5py.File(path, 'r')
        self.get_handlers(hdf5_file)
        self.load_sizes()
        
    def load_sizes(self):
        self.img_size_1 = self.X_train.shape[1]
        self.img_size_2 = self.X_train.shape[2]
        self.outputs_size = self.Y_train.shape[1]
        self.num_train_samples = self.X_train.shape[0]
        self.num_val_samples = self.X_val.shape[0]
        self.num_test_samples = self.X_test.shape[0]
    
    def get_handlers(self, file):
        self.X_train = file['train_data_x']
        self.Y_train = file['train_data_y']
        self.X_val = file['val_data_x']
        self.Y_val = file['val_data_y']
        self.X_test = file['test_data_x']
        self.Y_test = file['test_data_y']
    
    def store_method(self):
        return DBNNSave()

    def train_data_generator(self):
        generator = self._generator(self.X_train, self.Y_train)
        return generator

    def test_data_generator(self):
        generator = self._generator(self.X_val, self.Y_val)
        return generator

    def create_model(self):
        input_image = Input(shape=(self.img_size_1, self.img_size_2, 1))

        layer = Conv2D(filters=32, kernel_size=(3, 3))(input_image)
        layer = BatchNormalization(axis=1)(layer)
        layer = Activation('relu')(layer)
        layer = MaxPooling2D(pool_size=(2, 2))(layer)
        
        layer = Conv2D(filters=32, kernel_size=(3, 3))(input_image)
        layer = BatchNormalization(axis=1)(layer)
        layer = Activation('relu')(layer)
        layer = MaxPooling2D(pool_size=(2, 2))(layer)
        
        layer = Flatten()(layer)

        layer = Dense(self.outputs_size)(layer)
        layer = BatchNormalization(axis=1)(layer)
        output_layer = Activation('sigmoid')(layer)
        model = Model(inputs=input_image, outputs=output_layer)
        model.compile( optimizer='adam',
                      loss='binary_crossentropy',
                      metrics=[self.f1_score, self.precision, self.recall])
        return model

    def f1_score(self, y_true, y_pred):
        c1 = self.get_true_positive(y_true,y_pred)
        c2 = self.get_positive_pred(y_pred)
        c3 = self.get_positive_true(y_true)

        if c3 == 0:
            return 0

        precision = c1 / c2
        recall = c1 / c3
        f1_score = 2 * (precision * recall) / (precision + recall)
        return f1_score
    
    def precision(self,y_true,y_pred):
        c1 = self.get_true_positive(y_true,y_pred)
        c2 = self.get_positive_pred(y_pred)
        return c1/c2
    
    def recall(self,y_true,y_pred):
        c1 = self.get_true_positive(y_true,y_pred)
        c3 = self.get_positive_true(y_true)
        return c1/c3
    
    def get_true_positive(self,y_true,y_pred):
        return K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    
    def get_positive_pred(self,y_pred):
        return K.sum(K.round(K.clip(y_pred, 0, 1)))
    
    def get_positive_true(self,y_true):
        return K.sum(K.round(K.clip(y_true, 0, 1)))
    
    def _generator(self,X,Y):       
        while 1:
            batch_s = self.batch_size
            for i in range(X.shape[0] // self.batch_size):
                x_part = X[i*batch_s: (i+1)*batch_s]
                y_part = Y[i*batch_s: (i+1)*batch_s]
                if np.random.random_sample() < 0.1:
                    self.example_images.append(x_part[0])
                yield x_part, y_part
        
    def train(self):
        self.train_model(
            self.num_train_samples // self.batch_size,
            self.num_val_samples // self.batch_size,
            epochs=self.epochs
        )

# %%
retina = retinaNN()
retina.train()
# Out:
# Epoch 1/20
# 28/28 [==============================] - 26s 917ms/step - loss: 0.7854 - f1_score: 0.0433 - precision: 0.0224 - recall: 0.6783 - val_loss: 0.6872 - val_f1_score: 0.0297 - val_precision: 0.0154 - val_recall: 0.4033
# Epoch 2/20
# 28/28 [==============================] - 21s 748ms/step - loss: 0.7482 - f1_score: 0.0555 - precision: 0.0287 - recall: 0.8389 - val_loss: 0.8052 - val_f1_score: 0.0292 - val_precision: 0.0150 - val_recall: 0.5310
# Epoch 3/20
# 28/28 [==============================] - 21s 748ms/step - loss: 0.7130 - f1_score: 0.0654 - precision: 0.0339 - recall: 0.9267 - val_loss: 0.9291 - val_f1_score: 0.0310 - val_precision: 0.0159 - val_recall: 0.5824
# Epoch 4/20
# 28/28 [==============================] - 21s 744ms/step - loss: 0.6789 - f1_score: 0.0764 - precision: 0.0398 - recall: 0.9716 - val_loss: 0.8782 - val_f1_score: 0.0310 - val_precision: 0.0160 - val_recall: 0.5436
# Epoch 5/20
# 28/28 [==============================] - 21s 744ms/step - loss: 0.6564 - f1_score: 0.0849 - precision: 0.0444 - recall: 0.9828 - val_loss: 0.8106 - val_f1_score: 0.0306 - val_precision: 0.0158 - val_recall: 0.5079
# Epoch 6/20
# 28/28 [==============================] - 21s 745ms/step - loss: 0.6394 - f1_score: 0.0925 - precision: 0.0486 - recall: 0.9823 - val_loss: 0.7698 - val_f1_score: 0.0311 - val_precision: 0.0161 - val_recall: 0.4897
# Epoch 7/20
# 28/28 [==============================] - 21s 744ms/step - loss: 0.6237 - f1_score: 0.1029 - precision: 0.0543 - recall: 0.9858 - val_loss: 0.7430 - val_f1_score: 0.0337 - val_precision: 0.0174 - val_recall: 0.5123
# Epoch 8/20
# 28/28 [==============================] - 21s 743ms/step - loss: 0.6080 - f1_score: 0.1165 - precision: 0.0620 - recall: 0.9853 - val_loss: 0.7133 - val_f1_score: 0.0365 - val_precision: 0.0190 - val_recall: 0.4886
# Epoch 9/20
# 28/28 [==============================] - 21s 743ms/step - loss: 0.5935 - f1_score: 0.1324 - precision: 0.0710 - recall: 0.9869 - val_loss: 0.6890 - val_f1_score: 0.0330 - val_precision: 0.0172 - val_recall: 0.4266
# Epoch 10/20
# 28/28 [==============================] - 22s 787ms/step - loss: 0.5794 - f1_score: 0.1552 - precision: 0.0843 - recall: 0.9880 - val_loss: 0.6582 - val_f1_score: 0.0318 - val_precision: 0.0166 - val_recall: 0.3983
# Epoch 11/20
# 28/28 [==============================] - 22s 783ms/step - loss: 0.5652 - f1_score: 0.1846 - precision: 0.1019 - recall: 0.9913 - val_loss: 0.6302 - val_f1_score: 0.0313 - val_precision: 0.0164 - val_recall: 0.3445
# Epoch 12/20
# 28/28 [==============================] - 21s 743ms/step - loss: 0.5524 - f1_score: 0.2170 - precision: 0.1221 - recall: 0.9921 - val_loss: 0.6346 - val_f1_score: 0.0348 - val_precision: 0.0182 - val_recall: 0.3756
# Epoch 13/20
# 28/28 [==============================] - 22s 784ms/step - loss: 0.5402 - f1_score: 0.2517 - precision: 0.1445 - recall: 0.9932 - val_loss: 0.6185 - val_f1_score: 0.0395 - val_precision: 0.0208 - val_recall: 0.3932
# Epoch 14/20
# 28/28 [==============================] - 21s 741ms/step - loss: 0.5286 - f1_score: 0.2896 - precision: 0.1699 - recall: 0.9927 - val_loss: 0.6337 - val_f1_score: 0.0385 - val_precision: 0.0202 - val_recall: 0.4107
# Epoch 15/20
# 28/28 [==============================] - 21s 741ms/step - loss: 0.5173 - f1_score: 0.3301 - precision: 0.1985 - recall: 0.9929 - val_loss: 0.6288 - val_f1_score: 0.0389 - val_precision: 0.0205 - val_recall: 0.3838
# Epoch 16/20
# 28/28 [==============================] - 21s 742ms/step - loss: 0.5060 - f1_score: 0.3809 - precision: 0.2366 - recall: 0.9943 - val_loss: 0.6194 - val_f1_score: 0.0384 - val_precision: 0.0202 - val_recall: 0.3727
# Epoch 17/20
# 28/28 [==============================] - 21s 741ms/step - loss: 0.4951 - f1_score: 0.4324 - precision: 0.2771 - recall: 0.9956 - val_loss: 0.6370 - val_f1_score: 0.0390 - val_precision: 0.0205 - val_recall: 0.3951
# Epoch 18/20
# 28/28 [==============================] - 21s 743ms/step - loss: 0.4849 - f1_score: 0.4735 - precision: 0.3117 - recall: 0.9953 - val_loss: 0.6428 - val_f1_score: 0.0435 - val_precision: 0.0230 - val_recall: 0.4194
# Epoch 19/20
# 28/28 [==============================] - 22s 782ms/step - loss: 0.4745 - f1_score: 0.5278 - precision: 0.3604 - recall: 0.9950 - val_loss: 0.6057 - val_f1_score: 0.0365 - val_precision: 0.0193 - val_recall: 0.3335
# Epoch 20/20
# 28/28 [==============================] - 21s 741ms/step - loss: 0.4647 - f1_score: 0.5705 - precision: 0.4012 - recall: 0.9955 - val_loss: 0.6429 - val_f1_score: 0.0361 - val_precision: 0.0190 - val_recall: 0.3680

# %%
from sklearn.metrics import roc_curve, auc

def change_y_to_words(y):
    hdf5_file = h5py.File(retina.path_to_data, 'r')
    n_gram = hdf5_file.attrs['n_gram']
    predicted_words = []
    print(n_gram)
    for i in range(len(y)):
        if y[i] > 0.5:
            predicted_words.append(tuple(n_gram[i]))
    return predicted_words

def get_i_word(i):
    hdf5_file = h5py.File(retina.path_to_data, 'r')
    n_gram = hdf5_file.attrs['n_gram']
    return n_gram[i]

def get_model_quality(y_true,y_pred):
    c1 = sum(np.around(y_true*y_pred)) #TP
    c2 = sum(np.around(y_pred))
    c3 = sum(np.around(y_true))
    precision = c1/c2
    recall = c1 / c3
    f1_score = 2 * (precision * recall) / (precision + recall)
    return precision, recall, f1_score

w = len(retina.Y_train[0])
h = retina.Y_train.shape[0]
pred_y = [[0 for i in range(h)] for j in range(w)]
true_y = [[0 for i in range(h)] for j in range(w)]
print(len(pred_y))
def test_model():
    for i in range(10):
        x_test = retina.X_train[i:i+1]
        y_test = retina.Y_train[i]
        y_score = retina.model.predict(x_test)
        c = []
        for j in range(len(y_test)):
            pred_y[j][i] = y_test[j]
            true_y[j][i] = y_score[0][j]
            if y_score[0][j] > 0.5:
                c.append(1)
            else:
                c.append(0)
        #count = 0
        #for e in c:
        #    if(e == 1):
        #        count = count + 1
        #print(count)
        #count = 0
        #for e in y_test:
        #    if(e == 1):
        #        count = count + 1
        #print(count)
        #print(y_test)
        #print(np.array(c))
        #print()
        precision, recall, f1_score = get_model_quality(y_test,y_score[0])
        print(precision, recall, f1_score)
        #print(change_y_to_words(y_score[0]))
    
    aucs = []
    for i in range(len(pred_y)):
        roc_auc = generate_results(pred_y[i],true_y[i],i)
        aucs.append(roc_auc)
    
    print(np.nanmean(aucs))
test_model()
# Out:
# 1000
# 0.235294117647 0.903225806452 0.373333333333
# 0.0 nan nan
# 0.0212765957447 1.0 0.0416666666667
# 0.168224299065
# C:\Users\adam\AppData\Local\conda\conda\envs\inz_retina\lib\site-packages\ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in double_scalars
#  0.947368421053 0.285714285714
# 0.188679245283 0.869565217391 0.31007751938
# 0.227722772277 0.958333333333 0.368
# 0.154545454545 0.944444444444 0.265625
# 0.0802919708029 0.916666666667 0.147651006711
# 0.196721311475 0.96 0.326530612245
# 0.101851851852 0.916666666667 0.183333333333
# ['faza' 'późny']
# ['faza' 'wczesny']
# ['obraz' 'angiograficzny']
# ['późny' 'obraz']
# ['ukazować' 'faza']
# ['wszyscy' 'faza']
# ['hiperfluorescencja' 'odpowiadać']
# ['biegun' 'tylny']
# ['obrzęk' 'siatkówka']
# ['ognisko' 'hiperfluorescencja']
# C:\Users\adam\AppData\Local\conda\conda\envs\inz_retina\lib\site-packages\sklearn\metrics\ranking.py:571: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# ['ognisko' 'hipofluorescencja']
# ['wynikać' 'obecność']
# ['hipofluorescencja' 'odpowiadać']
# ['koniec' 'badanie']
# ['naczynia' 'siatkówka']
# ['laseroterapia' 'siatkówka']
# ['faza' 'kolejny']
# ['badanie' 'soct']
# ['brak' 'cech']
# ['widoczny' 'plamisty']
# ['wskazany' 'monitorować']
# ['odpowiadać' 'mikroaneuryzmaty']
# ['dołek' 'plamka']
# ['korelacja' 'obraz']
# ['norma' 'wiekowy']
# ['obraz' 'af']
# ['strefa' 'awaskularne']
# ['wskazany' 'korelacja']
# ['granica' 'norma']
# ['warstwa' 'barwnikowy']
# ['badanie' 'obraz']
# ['monitorować' 'zmiana']
# ['wypełnienie' 'naczynia']
# ['zmiana' 'badanie']
# ['wypełniać' 'naczynia']
# ['ubytek' 'rpe']
# ['kontrola' 'okulistyczny']
# ['wyrównanie' 'cukrzyca']
# ['obwód' 'siatkówka']
# ['siatkówka' 'faza']
# ['neowaskularyzacja' 'podsiatkówkowa']
# ['widoczny' 'zlokalizować']
# ['hiperfluorescencja' 'zlokalizować']
# ['tło' 'naczyniówkowy']
# ['stała' 'charakter']
# ['faza' 'żylny']
# ['uniesienie' 'siatkówka']
# ['widoczny' 'hiperfluorescencja']
# ['zmiana' 'naczyniowy']
# ['pomoc' 'soct']
# ['hiperfluorescencja' 'stała']
# ['faza' 'badanie']
# ['prawidłowy' 'wypełnienie']
# ['odpowiadać' 'krwotoczki']
# ['może' 'odpowiadać']
# ['plamka' 'widoczny']
# ['ukazować' 'prawidłowy']
# ['soct' 'cel']
# ['okresowy' 'kontrola']
# ['cech' 'obecność']
# ['obecność' 'neowaskularyzacja']
# ['obszar' 'hipofluorescencja']
# ['faza' 'tętniczy']
# ['widoczny' 'ognisko']
# ['wybroczyna' 'ognisko']
# ['wskazany' 'okresowy']
# ['krwotoczki' 'wybroczyna']
# ['znamię' 'barwnikowy']
# ['barwnikowy' 'siatkówka']
# ['faza' 'widoczny']
# ['tylny' 'widoczny']
# ['stała' 'monitorować']
# ['ograniczony' 'obrzęk']
# ['barwnikowy' 'naczyniówka']
# ['wskazany' 'stała']
# ['obecność' 'zanik']
# ['zcieńczenia' 'warstwa']
# ['odpowiadać' 'zmiana']
# ['wynik' 'af']
# ['odpowiadać' 'krwotok']
# ['siatkówka' 'widoczny']
# ['cech' 'uniesienie']
# ['siatkówka' 'norma']
# ['fluorescencja' 'tło']
# ['tarcza' 'ii']
# ['siatkówka' 'dochodzić']
# ['wskazany' 'normalizacja']
# ['delikatny' 'ognisko']
# ['krętość' 'naczynia']
# ['normalizacja' 'wyrównanie']
# ['krwotok' 'wybroczyna']
# ['zgodnie' 'wynik']
# ['punktowata' 'hiperfluorescencja']
# ['obraz' 'soct']
# ['charakter' 'koniec']
# ['norma' 'faza']
# ['żylny' 'widoczny']
# ['podsiatkówkowa' 'wskazany']
# ['siatkówka' 'zmiana']
# ['zanik' 'okołotarczowy']
# ['odpowiadać' 'znamię']
# ['plamisty' 'hipofluorescencja']
# ['ponad' 'plamka']
# ['siatkówka' 'zgodnie']
# ['poniżej' 'dołek']
# ['cel' 'ustalenie']
# ['jak' 'lecz']
# ['światło' 'czerwona']
# ['późny' 'obrzęk']
# ['hipofluorescencja' 'stała']
# ['mikroaneuryzmaty' 'obwód']
# ['siatkówka' 'obecność']
# ['wczesny' 'biegun']
# ['monitorować' 'pomoc']
# ['późny' 'wskazany']
# ['naczyniówka' 'wskazany']
# ['widoczny' 'światło']
# ['tętniczy' 'żylny']
# ['plamka' 'plamisty']
# ['odpowiadać' 'faza']
# ['dobrze' 'widoczny']
# ['widoczny' 'faza']
# ['żylny' 'ognisko']
# ['zmiana' 'podobny']
# ['czytelność' 'angiogram']
# ['nad' 'plamka']
# ['naczyniowy' 'faza']
# ['wynikać' 'zcieńczenia']
# ['zmiana' 'dobrze']
# ['wskazany' 'leczenie']
# ['badanie' 'zmiana']
# ['af' 'wskazywać']
# ['obraz' 'początkowy']
# ['obecność' 'aktywny']
# ['naczyniówkowy' 'wynikać']
# 1.0

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
def generate_results(y_test, y_score,i, plot=False):
    fpr, tpr, _ = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)
    if plot:
        plt.figure()
        plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
        plt.plot([0, 1], [0, 1], 'k--')
        plt.xlim([0.0, 1.05])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver operating characteristic curve')
        plt.show()
    if roc_auc > 0.7:
        print(get_i_word(i))
    #print('AUC: %f' % roc_auc)
    return roc_auc

# %%
import PIL
for img in retina.example_images[0:1]:
    img = img.reshape(74,100,3)
    
    #restore = lambda x: (x+3)*255
    #print(restore(img[0]))
    img = PIL.Image.fromarray(img[0])
    img.show()

# %%
hdf5_file = h5py.File(retina.path_to_data, 'r')
n_gram = hdf5_file.attrs['n_gram']
for g in n_gram:
    print(g)
# Out:
# ['faza' 'późny']
# ['faza' 'wczesny']
# ['obraz' 'angiograficzny']
# ['późny' 'obraz']
# ['ukazować' 'faza']
# ['wszyscy' 'faza']
# ['faza' 'mieszany']
# ['hiperfluorescencja' 'odpowiadać']
# ['biegun' 'tylny']
# ['obrzęk' 'siatkówka']
# ['ognisko' 'hiperfluorescencja']
# ['faza' 'angiogram']
# ['powodować' 'faza']
# ['angiograficzny' 'odpowiadać']
# ['angiogram' 'widoczny']
# ['ognisko' 'hipofluorescencja']
# ['wynikać' 'obecność']
# ['plamisty' 'hiperfluorescencja']
# ['odpowiadać' 'obecność']
# ['hipofluorescencja' 'odpowiadać']
# ['koniec' 'badanie']
# ['hiperfluorescencja' 'wynikać']
# ['naczynia' 'siatkówka']
# ['narastać' 'powodować']
# ['laseroterapia' 'siatkówka']
# ['faza' 'kolejny']
# ['intensywność' 'zmiana']
# ['badanie' 'soct']
# ['obraz' 'odpowiadać']
# ['brak' 'cech']
# ['nabłonek' 'barwnikowy']
# ['wczesny' 'widoczny']
# ['maskowanie' 'tło']
# ['zmiana' 'narastać']
# ['widoczny' 'plamisty']
# ['terapia' 'doszklistkowa']
# ['wskazany' 'monitorować']
# ['odpowiadać' 'mikroaneuryzmaty']
# ['rozpocząć' 'laseroterapia']
# ['dołek' 'plamka']
# ['amd' 'postać']
# ['korelacja' 'obraz']
# ['norma' 'wiekowy']
# ['retinopatia' 'cukrzycowy']
# ['bez' 'obrzęk']
# ['obraz' 'af']
# ['strefa' 'awaskularne']
# ['wskazany' 'korelacja']
# ['granica' 'norma']
# ['druz' 'siatkówka']
# ['plamka' 'bez']
# ['warstwa' 'barwnikowy']
# ['badan' 'soct']
# ['badanie' 'obraz']
# ['obecność' 'mikroaneuryzmaty']
# ['siatkówka' 'wskazany']
# ['monitorować' 'zmiana']
# ['wypełnienie' 'naczynia']
# ['zmiana' 'badanie']
# ['wypełniać' 'naczynia']
# ['ubytek' 'rpe']
# ['wskazany' 'uzupełnienie']
# ['obraz' 'obrzęk']
# ['siatkówka' 'obraz']
# ['uniesienie' 'warstwa']
# ['kontrola' 'okulistyczny']
# ['odpowiadać' 'blizna']
# ['wyrównanie' 'cukrzyca']
# ['uzupełnienie' 'diagnostyk']
# ['pojedynczy' 'ognisko']
# ['podjąć' 'decyzja']
# ['decyzja' 'terapeutyczny']
# ['mieszany' 'ukazować']
# ['obwód' 'siatkówka']
# ['siatkówka' 'faza']
# ['narastać' 'faza']
# ['delikatny' 'hiperfluorescencja']
# ['siatkówka' 'prawidłowy']
# ['obraz' 'uniesienie']
# ['neowaskularyzacja' 'podsiatkówkowa']
# ['widoczny' 'zlokalizować']
# ['późny' 'plamka']
# ['af' 'soct']
# ['obecność' 'druz']
# ['liczny' 'ognisko']
# ['odpowiadać' 'amd']
# ['hiperfluorescencja' 'zlokalizować']
# ['tło' 'naczyniówkowy']
# ['stała' 'charakter']
# ['punkt' 'hiperfluorescencja']
# ['stan' 'plamka']
# ['powodować' 'obraz']
# ['diagnostyk' 'badan']
# ['postać' 'wysiękowy']
# ['bez' 'cech']
# ['faza' 'żylny']
# ['mikroaneuryzmaty' 'siatkówka']
# ['rodzaj' 'zmiana']
# ['uniesienie' 'siatkówka']
# ['przebieg' 'amd']
# ['skroniowy' 'plamka']
# ['parametr' 'biochemiczny']
# ['monitorować' 'stan']
# ['plamka' 'pomoc']
# ['mieszany' 'widoczny']
# ['widoczny' 'hiperfluorescencja']
# ['prawidłowy' 'faza']
# ['zmiana' 'naczyniowy']
# ['swoić' 'intensywność']
# ['kontrola' 'wyrównanie']
# ['wczesny' 'maskowanie']
# ['pomoc' 'soct']
# ['wskazany' 'kontrola']
# ['mikroaneuryzmaty' 'faza']
# ['odpowiadać' 'druz']
# ['obszar' 'hiperfluorescencja']
# ['odpowiadać' 'ubytek']
# ['hiperfluorescencja' 'stała']
# ['makulopatia' 'wskazany']
# ['cech' 'patologiczny']
# ['faza' 'badanie']
# ['prawidłowy' 'wypełnienie']
# ['biochemiczny' 'cukrzyca']
# ['odpowiadać' 'krwotoczki']
# ['bez' 'cnv']
# ['powiększać' 'koniec']
# ['może' 'odpowiadać']
# ['plamka' 'widoczny']
# ['warstwa' 'nabłonek']
# ['ukazować' 'prawidłowy']
# ['barwnik' 'rpe']
# ['stać' 'kontrola']
# ['intensywność' 'faza']
# ['obszar' 'plamka']
# ['materiał' 'podsiatkówkowy']
# ['soct' 'cel']
# ['patologiczny' 'fluorescencja']
# ['kolejny' 'powodować']
# ['wyraźnie' 'ograniczony']
# ['okresowy' 'kontrola']
# ['nasilać' 'koniec']
# ['cech' 'obecność']
# ['przegrupowanie' 'barwnik']
# ['nieregularny' 'hiperfluorescencja']
# ['zmiana' 'kwalifikować']
# ['druz' 'ubytek']
# ['blizna' 'laseroterapia']
# ['obrzęk' 'plamka']
# ['hiperfluorescencja' 'intensywność']
# ['stabilizacja' 'parametr']
# ['cukrzyca' 'rozpocząć']
# ['ubytek' 'okienkowate']
# ['obecność' 'neowaskularyzacja']
# ['plamka' 'faza']
# ['zwiększać' 'swoić']
# ['wskazany' 'stabilizacja']
# ['intensywność' 'narastać']
# ['obszar' 'hipofluorescencja']
# ['późny' 'widoczny']
# ['faza' 'tętniczy']
# ['narastający' 'hiperfluorescencja']
# ['widoczny' 'obszar']
# ['okolica' 'plamka']
# ['arkada' 'naczyniowy']
# ['obraz' 'siatkówka']
# ['obrzęk' 'bez']
# ['widoczny' 'ognisko']
# ['wybroczyna' 'ognisko']
# ['plamka' 'obraz']
# ['nasilać' 'powiększać']
# ['hiperfluorescencja' 'nasilać']
# ['faza' 'obraz']
# ['obecność' 'ubytek']
# ['wskazany' 'okresowy']
# ['obraz' 'kliniczny']
# ['wywołać' 'obecność']
# ['podsiatkówkowy' 'faza']
# ['krwotoczki' 'wybroczyna']
# ['tło' 'materiał']
# ['hiperfluorescencja' 'zwiększać']
# ['odpowiadać' 'przegrupowanie']
# ['regresja' 'zmiana']
# ['znamię' 'barwnikowy']
# ['barwnikowy' 'siatkówka']
# ['odpowiadać' 'błona']
# ['dna' 'oko']
# ['ograniczony' 'hiperfluorescencja']
# ['faza' 'widoczny']
# ['wskazany' 'stać']
# ['ukazować' 'obecność']
# ['widoczny' 'liczny']
# ['pojawiać' 'delikatny']
# ['kolejny' 'faza']
# ['tylny' 'widoczny']
# ['obraz' 'ograniczony']
# ['obecność' 'liczny']
# ['iniekcja' 'doszklistkowe']
# ['cnv' 'wskazany']
# ['późny' 'powodować']
# ['narząd' 'wzrok']
# ['wskazany' 'pilny']
# ['obecność' 'cnv']
# ['postać' 'suchy']
# ['hipofluorescencja' 'plamiec']
# ['stała' 'monitorować']
# ['zmiana' 'jak']
# ['hiperfluorescencja' 'wywołać']
# ['częsty' 'plamka']
# ['obecność' 'ukryć']
# ['ograniczony' 'obrzęk']
# ['przeciek' 'okołonaczyniowe']
# ['plamka' 'wskazany']
# ['oba' 'oko']
# ['barwnikowy' 'naczyniówka']
# ['stan' 'narząd']
# ['podobny' 'zmiana']
# ['dochodzić' 'plamka']
# ['wskazany' 'stała']
# ['hiperfluorescencja' 'nieznacznie']
# ['zanik' 'rpe']
# ['pilny' 'rozpocząć']
# ['obecność' 'zanik']
# ['obraz' 'prawidłowy']
# ['badanie' 'poprzedni']
# ['nieproliferacyjny' 'retinopatia']
# ['plamka' 'hiperfluorescencja']
# ['okres' 'badanie']
# ['cały' 'okres']
# ['zlokalizować' 'skroniowy']
# ['rpe' 'wskazany']
# ['zcieńczenia' 'warstwa']
# ['błona' 'neowaskularna']
# ['badanie' 'widoczny']
# ['uzupełnić' 'badan']
# ['diagnostyka' 'uzupełnić']
# ['ukazować' 'liczny']
# ['odpowiadać' 'zmiana']
# ['ubytek' 'zakres']
# ['rozlec' 'hiperfluorescencja']
# ['przebyć' 'laseroterapia']
# ['liczny' 'punkt']
# ['zmiana' 'terapia']
# ['ukazować' 'pojedynczy']
# ['barwnikowy' 'obraz']
# ['ukazować' 'podobny']
# ['początkowy' 'zmiana']
# ['angiograficzny' 'może']
# ['poważny' 'wskazany']
# ['cukrzyca' 'pilny']
# ['odpowiadać' 'wybroczyna']
# ['zwłóknienie' 'podsiatkówkowy']
# ['cel' 'podjąć']
# ['wynik' 'af']
# ['wzrok' 'poważny']
# ['ciało' 'szklisty']
# ['zapalenie' 'rpe']
# ['cukrzycowy' 'makulopatia']
# ['obraz' 'ogniskowy']
# ['drobne' 'ognisko']
# ['ostrość' 'wzrok']
# ['wskazany' 'rozważyć']
# ['nieznacznie' 'narastać']
# ['odpowiadać' 'krwotok']
# ['drobnoplamisty' 'hiperfluorescencja']
# ['wczesny' 'ognisko']
# ['hiperfluorescencja' 'wokół']
# ['stać' 'wszyscy']
# ['postać' 'amd']
# ['cech' 'obrzęk']
# ['wczesny' 'liczny']
# ['oko' 'lewy']
# ['mieszany' 'ognisko']
# ['widoczny' 'rozlec']
# ['hiperfluorescencja' 'biegun']
# ['siatkówka' 'ubytek']
# ['siatkówka' 'uniesienie']
# ['rpe' 'druz']
# ['siatkówka' 'biegun']
# ['rpe' 'faza']
# ['tarcza' 'wzrokowy']
# ['zwyrodnienie' 'plamka']
# ['leczenie' 'pomoc']
# ['widoczny' 'pojedynczy']
# ['siatkówka' 'widoczny']
# ['ognisko' 'przebyć']
# ['znaczny' 'regresja']
# ['siatkówka' 'intensywność']
# ['siatkówka' 'zajmować']
# ['kolejny' 'ukazować']
# ['cukrzycowy' 'wskazany']
# ['obszar' 'zanik']
# ['obszar' 'plamisty']
# ['pomoc' 'iniekcja']
# ['zmiana' 'odpowiadać']
# ['kontrast' 'dna']
# ['ukryć' 'cnv']
# ['soct' 'podjąć']
# ['blizna' 'zapalenie']
# ['zlokalizować' 'biegun']
# ['obecność' 'rozległy']
# ['rpe' 'obraz']
# ['cech' 'uniesienie']
# ['siatkówka' 'norma']
# ['fluorescencja' 'tło']
# ['okienkowate' 'nabłonek']
# ['tło' 'krwotoczki']
# ['odpowiadać' 'retinopatia']
# ['intensywność' 'fluorescencja']
# ['pęczek' 'tarczowy']
# ['tarcza' 'ii']
# ['rozważyć' 'terapia']
# ['widoczny' 'wyraźnie']
# ['laseroterapia' 'faza']
# ['kliniczny' 'af']
# ['arkada' 'skroniowy']
# ['siatkówka' 'dochodzić']
# ['liczny' 'obszar']
# ['obraz' 'masywny']
# ['wskazany' 'laseroterapia']
# ['zlokalizować' 'plamiec']
# ['okienkowate' 'rpe']
# ['naczynia' 'żylny']
# ['pomoc' 'oct']
# ['kwalifikować' 'leczenie']
# ['obraz' 'plamka']
# ['ukazować' 'nieregularny']
# ['jak' 'badanie']
# ['hiperfluorescencja' 'powodować']
# ['skroniowy' 'górny']
# ['hipofluorescencja' 'biegun']
# ['hipofluorescencja' 'wynikać']
# ['wskazany' 'normalizacja']
# ['nieprawidłowy' 'obraz']
# ['uniesienie' 'rpe']
# ['obecność' 'zwłóknienie']
# ['cukrzyca' 'laseroterapia']
# ['siatkówkowy' 'naczyniówkowy']
# ['hiperfluorescencja' 'plamiec']
# ['delikatny' 'ognisko']
# ['ilość' 'barwnik']
# ['barwnikowy' 'wskazany']
# ['plamka' 'intensywność']
# ['widoczny' 'maskowanie']
# ['masywny' 'obrzęk']
# ['błona' 'cnv']
# ['kolejny' 'intensywność']
# ['krętość' 'naczynia']
# ['normalizacja' 'wyrównanie']
# ['nieznacznie' 'nasilać']
# ['mała' 'ilość']
# ['krwotok' 'wybroczyna']
# ['zgodnie' 'wynik']
# ['wzdłuż' 'arkada']
# ['ukazować' 'cały']
# ['uzupełnienie' 'laseroterapia']
# ['ubytek' 'okienkowaty']
# ['poszerzyć' 'strefa']
# ['badanie' 'faza']
# ['oko' 'prawa']
# ['badan' 'oct']
# ['wybroczyna' 'krwotoczki']
# ['widoczny' 'nieregularny']
# ['zanik' 'warstwa']
# ['zanik' 'siatkówkowy']
# ['doszklistkowa' 'inhibitor']
# ['ogniskowy' 'obrzęk']
# ['tylny' 'odpowiadać']
# ['kwalifikacja' 'terapia']
# ['zaawansowanie' 'zmiana']
# ['zmiana' 'bardziej']
# ['bardziej' 'nasilić']
# ['cnv' 'obraz']
# ['ukazować' 'plamisty']
# ['punktowata' 'hiperfluorescencja']
# ['hiperfluorescencja' 'obraz']
# ['proliferacyjny' 'retinopatia']
# ['zajmować' 'też']
# ['angiograficzny' 'prawidłowy']
# ['widoczny' 'drobnoplamisty']
# ['amd' 'wskazany']
# ['widoczny' 'delikatny']
# ['zakres' 'warstwa']
# ['zakres' 'rpe']
# ['początkowy' 'strefa']
# ['obszar' 'równik']
# ['poniżej' 'plamka']
# ['ośrodek' 'optyczny']
# ['późny' 'bez']
# ['blizna' 'przebyć']
# ['obraz' 'soct']
# ['naczyniowy' 'strefa']
# ['charakter' 'koniec']
# ['norma' 'faza']
# ['charakter' 'odpowiadać']
# ['cukrzycowy' 'nieproliferacyjny']
# ['rozległy' 'obszar']
# ['kwalifikować' 'terapia']
# ['przebyć' 'zapalenie']
# ['przebieg' 'naczynia']
# ['pilny' 'terapia']
# ['przy' 'arkada']
# ['fluorescencja' 'narastać']
# ['pierścieniowaty' 'ognisko']
# ['widoczny' 'punkt']
# ['żylny' 'widoczny']
# ['podsiatkówkowa' 'przebieg']
# ['zlokalizować' 'okolica']
# ['krwotoczki' 'faza']
# ['ukryć' 'neowaskularyzacja']
# ['angiogram' 'ukazować']
# ['hiperfluorescencja' 'hiperfluorescencja']
# ['zakres' 'norma']
# ['zmiana' 'zwyrodnieniowy']
# ['barwnikowy' 'brak']
# ['wokół' 'dołek']
# ['cech' 'siatkówka']
# ['późny' 'brak']
# ['podsiatkówkowa' 'wskazany']
# ['rozległy' 'hipofluorescencja']
# ['związać' 'wiek']
# ['soct' 'af']
# ['odpowiadać' 'początkowy']
# ['przebieg' 'postać']
# ['siatkówka' 'zmiana']
# ['retinopatia' 'nieproliferacyjny']
# ['typowy' 'dla']
# ['tylny' 'faza']
# ['obraz' 'jak']
# ['hiperfluorescencja' 'obecność']
# ['odpowiadać' 'zanik']
# ['prawidłowy' 'brak']
# ['hiperfluorescencja' 'skroniowy']
# ['zanik' 'okołotarczowy']
# ['plamka' 'obszar']
# ['obraz' 'może']
# ['odpowiadać' 'znamię']
# ['plamisty' 'hipofluorescencja']
# ['mieszany' 'biegun']
# ['prawidłowy' 'wszyscy']
# ['plamka' 'makulopatia']
# ['ponad' 'plamka']
# ['angiogram' 'odpowiadać']
# ['zmiana' 'stać']
# ['późny' 'hiperfluorescencja']
# ['środkowa' 'siatkówka']
# ['hiperfluorescencja' 'mikroaneuryzmaty']
# ['liczny' 'drobne']
# ['cały' 'biegun']
# ['mieszany' 'pojedynczy']
# ['doszklistkowa' 'wskazany']
# ['kontynuacja' 'laseroterapia']
# ['siatkówka' 'zgodnie']
# ['plamka' 'związać']
# ['suchy' 'wskazany']
# ['hipofluorescencja' 'otoczyć']
# ['kwalifikować' 'pilny']
# ['wysiękowy' 'wskazany']
# ['narastający' 'faza']
# ['widoczny' 'pierścieniowaty']
# ['wysięk' 'krwotoczki']
# ['intensywność' 'nieznacznie']
# ['wskazany' 'rozpocząć']
# ['awaskularne' 'faza']
# ['stan' 'siatkówka']
# ['obraz' 'rozlany']
# ['przy' 'tarcza']
# ['początkowy' 'retinopatia']
# ['cnv' 'przebieg']
# ['odpowiadać' 'zaawansowana']
# ['hiperfluorescencja' 'otoczyć']
# ['poniżej' 'dołek']
# ['rpe' 'hipofluorescencja']
# ['siatkówka' 'rodzaj']
# ['leczenie' 'operacyjny']
# ['naczynia' 'faza']
# ['awaskularne' 'obwód']
# ['uzupełniający' 'badan']
# ['uniesienie' 'obrzęk']
# ['cel' 'kwalifikacja']
# ['mikroaneuryzmaty' 'intensywność']
# ['strefa' 'hipofluorescencja']
# ['ubytek' 'nabłonek']
# ['żyć' 'środkowa']
# ['siatkówka' 'brak']
# ['patologiczny' 'unaczynienie']
# ['leczenie' 'można']
# ['punkt' 'hipofluorescencja']
# ['naczyniówkowy' 'materiał']
# ['af' 'odpowiadać']
# ['badanie' 'odpowiadać']
# ['niewielki' 'obrzęk']
# ['obrzęk' 'obraz']
# ['zająć' 'plamka']
# ['tarczowy' 'plamkowe']
# ['widoczny' 'obrzęk']
# ['obrzęk' 'uniesienie']
# ['zmiana' 'faza']
# ['cel' 'ustalenie']
# ['wokół' 'tarcza']
# ['jak' 'lecz']
# ['mieszany' 'delikatny']
# ['drobny' 'hiperfluorescencja']
# ['też' 'obszar']
# ['pilny' 'laseroterapia']
# ['obraz' 'zmiana']
# ['plamka' 'obwód']
# ['obecność' 'błona']
# ['można' 'wykluczyć']
# ['pierścieniowaty' 'hiperfluorescencja']
# ['światło' 'czerwona']
# ['drobne' 'naczynia']
# ['zmiana' 'prawidłowy']
# ['ukazować' 'ognisko']
# ['ukazować' 'wszyscy']
# ['mały' 'nasilenie']
# ['błona' 'włóknisty']
# ['kontrola' 'soct']
# ['móc' 'odpowiadać']
# ['skroniowy' 'dołowić']
# ['plamiec' 'wokół']
# ['plamka' 'ognisko']
# ['wokół' 'pojawiać']
# ['barwnikowy' 'obrzęk']
# ['wskazany' 'kontynuacja']
# ['narastać' 'znacznie']
# ['widoczny' 'strefa']
# ['późny' 'obrzęk']
# ['obwód' 'widoczny']
# ['dołowić' 'plamka']
# ['wokół' 'plamka']
# ['skroniowy' 'częsty']
# ['widoczny' 'fluorescencja']
# ['wskazany' 'obserwacja']
# ['hipofluorescencja' 'stała']
# ['otoczyć' 'delikatny']
# ['okienkowaty' 'rpe']
# ['mikroaneuryzmaty' 'obwód']
# ['naczyniowy' 'obwód']
# ['badanie' 'elektrofizjologiczny']
# ['zlokalizować' 'nosowo']
# ['ukazować' 'zlokalizować']
# ['początkowy' 'obrzęk']
# ['odpowiadać' 'rozległy']
# ['rozważyć' 'leczenie']
# ['hiperfluorescencja' 'faza']
# ['siatkówka' 'zmysłowy']
# ['rozległy' 'hiperfluorescencja']
# ['liczny' 'druz']
# ['siatkówka' 'znaczny']
# ['diagnostyk' 'badanie']
# ['siatkówka' 'obszar']
# ['związać' 'obecność']
# ['wywołać' 'zcieńczenia']
# ['plamka' 'zmiana']
# ['cnv' 'obrzęk']
# ['zapalenie' 'nabłonek']
# ['nieznacznie' 'narastający']
# ['tylny' 'prawidłowy']
# ['laseroterapia' 'widoczny']
# ['zlokalizować' 'wokół']
# ['zmiana' 'powodować']
# ['siatkówka' 'zająć']
# ['makulopatia' 'cukrzycowy']
# ['hiperfluorescencja' 'związać']
# ['rozlec' 'obszar']
# ['amd' 'rodzaj']
# ['opisywać' 'obszar']
# ['plamiec' 'faza']
# ['odpowiadać' 'epiteliopatia']
# ['klasyczny' 'cnv']
# ['tylny' 'plamisty']
# ['też' 'okolica']
# ['fluorescencja' 'ciało']
# ['narastać' 'hiperfluorescencja']
# ['obszar' 'maskowanie']
# ['siatkówka' 'obecność']
# ['widoczny' 'hipofluorescencja']
# ['okolica' 'tarcza']
# ['ukazować' 'narastający']
# ['skroniowy' 'dołek']
# ['oko' 'wskazany']
# ['zmiana' 'wskazany']
# ['przegrupowanie' 'rpe']
# ['materiał' 'faza']
# ['ograniczony' 'siatkówka']
# ['tylny' 'ognisko']
# ['terapeutyczny' 'dotyczyć']
# ['widoczny' 'biegun']
# ['kontrola' 'stan']
# ['skroniowy' 'arkada']
# ['dolny' 'częsty']
# ['tylny' 'hiperfluorescencja']
# ['obecność' 'klasyczny']
# ['wczesny' 'biegun']
# ['monitorować' 'pomoc']
# ['krwotoczki' 'pojedynczy']
# ['nieznacznie' 'powiększać']
# ['wczesny' 'delikatny']
# ['przypadek' 'progresja']
# ['wzgląd' 'mała']
# ['zamknięcie' 'naczynia']
# ['hiperfluorescencja' 'poniżej']
# ['skroniowy' 'dolny']
# ['tylny' 'obraz']
# ['ognisko' 'laseroterapia']
# ['widoczny' 'drobne']
# ['późny' 'wskazany']
# ['krwotok' 'podsiatkówkowy']
# ['mieszany' 'liczny']
# ['hipofluorescencja' 'krwotoczki']
# ['zajmować' 'obszar']
# ['barwnik' 'obraz']
# ['lecz' 'mały']
# ['naczynia' 'kontrast']
# ['naczynia' 'biegun']
# ['klasyczny' 'neowaskularyzacja']
# ['podsiatkówkowy' 'przebieg']
# ['ukazować' 'obszar']
# ['mikroaneuryzmaty' 'początkowy']
# ['obraz' 'istotny']
# ['odpowiadać' 'obrzęk']
# ['ukazować' 'biegun']
# ['naczyniówka' 'wskazany']
# ['ukazować' 'rozległy']
# ['warstwa' 'rpe']
# ['nierównomierny' 'wypełnienie']
# ['dość' 'liczny']
# ['hiperfluorescencja' 'obszar']
# ['naczyniówkowy' 'wywołać']
# ['punktowy' 'mieć']
# ['plamka' 'odpowiadać']
# ['wczesny' 'nieregularny']
# ['obwód' 'początkowy']
# ['przebieg' 'zwyrodnienie']
# ['wskazany' 'diagnostyk']
# ['af' 'oct']
# ['hipofluorescencja' 'wokół']
# ['plamiec' 'widoczny']
# ['neowaskularna' 'przebieg']
# ['hiperfluorescencjanasilać' 'powiększać']
# ['obecność' 'znamię']
# ['porównanie' 'badanie']
# ['wiekowy' 'wskazany']
# ['górny' 'widoczny']
# ['plamka' 'hiperfluorescencjanasilać']
# ['okulistyczny' 'badanie']
# ['plamka' 'ciężki']
# ['powodować' 'obecność']
# ['widoczny' 'światło']
# ['rpe' 'brak']
# ['tętniczy' 'widoczny']
# ['nieproliferacyjny' 'wskazany']
# ['hiperfluorescencja' 'przy']
# ['intensywność' 'powodować']
# ['kontrast' 'prawidłowy']
# ['początkowy' 'makulopatia']
# ['postępowanie' 'terapeutyczny']
# ['odpowiadać' 'uniesienie']
# ['siatkówka' 'badanie']
# ['naczynia' 'naczyniówka']
# ['charakter' 'zmiana']
# ['zwiększyć' 'krętość']
# ['błona' 'nasiatkówkowa']
# ['kwalifikacja' 'leczenie']
# ['pojawiać' 'hiperfluorescencja']
# ['faza' 'hiperfluorescencja']
# ['tylny' 'dochodzić']
# ['hiperfluorescencja' 'narastać']
# ['wzmóc' 'krętość']
# ['krwotoczki' 'intensywność']
# ['wynikać' 'mikroaneuryzmaty']
# ['hipofluorescencja' 'intensywność']
# ['prawidłowy' 'wskazany']
# ['rozlany' 'obrzęk']
# ['wskazany' 'terapia']
# ['górny' 'częsty']
# ['obecność' 'masywny']
# ['dolny' 'skroniowy']
# ['panfotokoagulacja' 'oba']
# ['cech' 'cnv']
# ['rozległy' 'obrzęk']
# ['hiperfluorescencja' 'tło']
# ['błona' 'podsiatkówkowa']
# ['zaawansowana' 'retinopatia']
# ['można' 'kontynuować']
# ['hiperfluorescencja' 'móc']
# ['rpe' 'przebieg']
# ['skroniowy' 'góra']
# ['owalny' 'ognisko']
# ['późny' 'cech']
# ['tętniczy' 'żylny']
# ['plamiec' 'hiperfluorescencja']
# ['należeć' 'rozważyć']
# ['chwila' 'obecna']
# ['rozlec' 'hipofluorescencja']
# ['znacznie' 'powodować']
# ['późny' 'niewielki']
# ['nad' 'zmiana']
# ['ubytek' 'warstwa']
# ['plamisty' 'narastać']
# ['plamka' 'badanie']
# ['intensywność' 'ulegać']
# ['wysoki' 'krótkowzroczność']
# ['progresja' 'zmiana']
# ['nieproliferacyjny' 'makulopatia']
# ['wzrok' 'kwalifikować']
# ['wczesny' 'obszar']
# ['jednooczność' 'wskazany']
# ['otoczyć' 'pierścień']
# ['plamka' 'plamisty']
# ['rozważyć' 'laseroterapia']
# ['góra' 'plamka']
# ['rozległy' 'zanik']
# ['wokół' 'on']
# ['obrzęk' 'obwód']
# ['bez' 'strefa']
# ['nieregularny' 'hipofluorescencja']
# ['angiograficzny' 'biegun']
# ['obraz' 'obraz']
# ['ognisko' 'odpowiadać']
# ['wczesny' 'poszerzyć']
# ['hipofluorescencja' 'tło']
# ['hipofluorescencja' 'wywołać']
# ['zwyrodnieniowy' 'plamka']
# ['obecność' 'obrzęk']
# ['laseroterapia' 'ogniskowa']
# ['rpe' 'widoczny']
# ['odpowiadać' 'faza']
# ['odpowiadać' 'przebyć']
# ['charakter' 'wynikać']
# ['wczesny' 'punkt']
# ['dobrze' 'widoczny']
# ['świecić' 'tło']
# ['obraz' 'rozległy']
# ['mikroaneuryzmaty' 'ognisko']
# ['siatkówka' 'nieproliferacyjny']
# ['naczynia' 'nad']
# ['widoczny' 'faza']
# ['stać' 'koniec']
# ['krwotoczki' 'ognisko']
# ['hiperfluorescencja' 'narastający']
# ['żylny' 'ognisko']
# ['tylny' 'obwód']
# ['wysiękowy' 'postać']
# ['podsiatkówkowa' 'faza']
# ['zmiana' 'nieznacznie']
# ['otoczyć' 'hipofluorescencja']
# ['nosowy' 'częsty']
# ['obecność' 'podsiatkówkowy']
# ['obraz' 'oct']
# ['dolny' 'widoczny']
# ['pozaangiogram' 'zakres']
# ['cnv' 'amd']
# ['hiperfluorescencja' 'powiększać']
# ['błona' 'przedsiatkówkowa']
# ['terapia' 'anta']
# ['mikroaneuryzmaty' 'obszar']
# ['wskazany' 'parametr']
# ['krwotoczki' 'wysięk']
# ['liczny' 'plamisty']
# ['ukryć' 'błona']
# ['rpe' 'ognisko']
# ['cukrzycowy' 'oba']
# ['odpowiadać' 'może']
# ['pilny' 'panfotokoagulacja']
# ['zmiana' 'podobny']
# ['górny' 'skroniowy']
# ['praktyczny' 'jednooczność']
# ['wzgląd' 'praktyczny']
# ['włóknisty' 'przebieg']
# ['druz' 'miękki']
# ['płatkowaty' 'hiperfluorescencja']
# ['angiograficzny' 'potwierdzać']
# ['czytelność' 'angiogram']
# ['awaskularne' 'wskazany']
# ['plamisty' 'ognisko']
# ['odpowiadać' 'csr']
# ['powiększać' 'faza']
# ['widoczny' 'zmiana']
# ['siatkówka' 'częściowy']
# ['żylny' 'siatkówka']
# ['barwnik' 'faza']
# ['widoczny' 'drobny']
# ['wykluczyć' 'obecność']
# ['wybroczyna' 'faza']
# ['pozaangiogram' 'prawidłowy']
# ['awaskularne' 'intensywność']
# ['narastać' 'koniec']
# ['łączny' 'analiza']
# ['widoczny' 'rozległy']
# ['otoczyć' 'hiperfluorescencja']
# ['zmiana' 'obraz']
# ['laseroterapia' 'wskazany']
# ['faza' 'powodować']
# ['zastój' 'barwnik']
# ['soct' 'kliniczny']
# ['tarcza' 'widoczny']
# ['stan' 'ośrodek']
# ['rozdąć' 'drobne']
# ['obraz' 'widoczny']
# ['obszar' 'narastający']
# ['odpowiadać' 'nieproliferacyjny']
# ['szklisty' 'proliferacyjny']
# ['wskazany' 'konsultacja']
# ['przebieg' 'wysoki']
# ['siatkówka' 'częściowo']
# ['tarczowy' 'plamkowy']
# ['wzrok' 'bardzo']
# ['bardzo' 'poważny']
# ['obszar' 'pęczek']
# ['zakrzep' 'gałązka']
# ['plamka' 'siatkówka']
# ['laseroterapia' 'obwód']
# ['nad' 'plamka']
# ['zmiana' 'on']
# ['plamisty' 'narastający']
# ['hipofluorescencja' 'hiperfluorescencja']
# ['oct' 'af']
# ['łączny' 'ocena']
# ['powyżej' 'plamka']
# ['wykonać' 'uzupełniający']
# ['angiograficzny' 'brak']
# ['siatkówka' 'można']
# ['pojedynczy' 'zmiana']
# ['naczyniowy' 'faza']
# ['obecność' 'obszar']
# ['wynikać' 'zcieńczenia']
# ['nieprawidłowość' 'naczyniowy']
# ['przebyć' 'zakrzep']
# ['krwotoczki' 'hiperfluorescencja']
# ['zmiana' 'dobrze']
# ['naczyniowy' 'początkowy']
# ['hiperfluorescencja' 'tarcza']
# ['wynikać' 'maskowanie']
# ['ukazować' 'hiperfluorescencja']
# ['mieć' 'faza']
# ['tylny' 'intensywność']
# ['masywny' 'zwłóknienie']
# ['makulopatia' 'stan']
# ['arkada' 'dolny']
# ['hiperfluorescencja' 'powyżej']
# ['nieznacznie' 'zwiększać']
# ['ulegać' 'zmiana']
# ['naczynia' 'prawidłowy']
# ['ograniczony' 'obszar']
# ['dość' 'rozległy']
# ['bez' 'patologiczny']
# ['okrągły' 'ognisko']
# ['aktywny' 'cnv']
# ['naczyniówkowy' 'obraz']
# ['pierścień' 'hipofluorescencja']
# ['angiograficzny' 'soct']
# ['kliniczny' 'angiograficzny']
# ['wybroczyna' 'pojedynczy']
# ['widoczny' 'owalny']
# ['wysycić' 'kontrast']
# ['daleki' 'postępowanie']
# ['druz' 'faza']
# ['tło' 'pojawiać']
# ['zmiana' 'plamiec']
# ['badan' 'usg']
# ['widoczny' 'naczynia']
# ['częściowy' 'zająć']
# ['wysięk' 'faza']
# ['postać' 'zanikowy']
# ['terapeutyczny' 'iniekcja']
# ['dawać' 'faza']
# ['wskazany' 'leczenie']
# ['neowaskularyzacja' 'naczyniowy']
# ['obecność' 'wysięk']
# ['kliniczny' 'cel']
# ['angiograficzny' 'ukazować']
# ['siatkówka' 'stan']
# ['pojedynczy' 'punkt']
# ['af' 'podjąć']
# ['zakrzep' 'żyć']
# ['obserwacja' 'monitorować']
# ['wskazanie' 'laseroterapia']
# ['suplementacja' 'dieta']
# ['późny' 'zmiana']
# ['laseroterapia' 'zmiana']
# ['zmniejszyć' 'wyrazistość']
# ['badanie' 'angiograficzny']
# ['przebieg' 'wysiękowy']
# ['obecność' 'blizna']
# ['strefa' 'awaskularna']
# ['ustalenie' 'postępowanie']
# ['wokół' 'widoczny']
# ['nieregularny' 'ognisko']
# ['ponad' 'dołek']
# ['badanie' 'nieprawidłowy']
# ['obrzęk' 'wskazany']
# ['siatkówka' 'bez']
# ['obrzęk' 'widoczny']
# ['angiograficzny' 'typowy']
# ['nosowo' 'dołowić']
# ['hiperfluorescencja' 'druz']
# ['widoczny' 'początkowy']
# ['wczesny' 'rozległy']
# ['stopniowo' 'nasilać']
# ['wskazany' 'łączny']
# ['wczesny' 'ukazować']
# ['obszar' 'obwód']
# ['nieznacznie' 'swoić']
# ['fluorescencja' 'wynikać']
# ['analiza' 'obraz']
# ['badanie' 'zmiana']
# ['hiperfluorescencja' 'ponad']
# ['af' 'wskazywać']
# ['plamka' 'angiograficznie']
# ['angiograficznie' 'prawidłowy']
# ['naczyniowy' 'widoczny']
# ['okołonaczyniowe' 'intensywność']
# ['plamisty' 'nieregularny']
# ['widoczny' 'świecić']
# ['wczesny' 'punktowata']
# ['stała' 'wszyscy']
# ['równik' 'widoczny']
# ['stała' 'faza']
# ['wskazany' 'kwalifikacja']
# ['powiększać' 'nasilać']
# ['żylny' 'pojawiać']
# ['warstwa' 'sensoryczny']
# ['hiperfluorescencja' 'cały']
# ['obszar' 'zmiana']
# ['amd' 'suchy']
# ['siatkówka' 'fluorescencja']
# ['soct' 'przypadek']
# ['siatkówka' 'obrzęk']
# ['obrzęk' 'biegun']
# ['siatkówka' 'obwód']
# ['panfotokoagulacja' 'siatkówka']
# ['okulistyczny' 'wraz']
# ['podjąć' 'leczenie']
# ['zmiana' 'ośrodek']
# ['wyrazistość' 'powodować']
# ['późny' 'badanie']
# ['nasilać' 'faza']
# ['siatkówka' 'kontrast']
# ['krwotoczki' 'liczny']
# ['naczyniowy' 'obraz']
# ['obraz' 'początkowy']
# ['obszar' 'biegun']
# ['angiogram' 'plamisty']
# ['pod' 'plamka']
# ['af' 'cel']
# ['odpowiadać' 'ukryć']
# ['masywny' 'hiperfluorescencja']
# ['obecność' 'aktywny']
# ['odpowiadać' 'zamknięcie']
# ['wczesny' 'plamisty']
# ['soct' 'wskazywać']
# ['obustronny' 'panfotokoagulacja']
# ['zlokalizować' 'okołodołkowo']
# ['światło' 'bezczerwienny']
# ['rpe' 'obecność']
# ['obraz' 'zastój']
# ['rozległy' 'ognisko']
# ['ukazować' 'nierównomierny']
# ['zlokalizować' 'ponad']
# ['ciężki' 'makulopatia']
# ['odpowiadać' 'dystrofia']
# ['późny' 'charakter']
# ['obszar' 'zwiększyć']
# ['równik' 'siatkówka']
# ['góra' 'dołek']
# ['cukrzyca' 'kontynuacja']
# ['ukazować' 'rozlec']
# ['badanie' 'af']
# ['odpowiadać' 'makulopatia']
# ['lokalizacja' 'zmiana']
# ['naczyniowy' 'obszar']
# ['liczny' 'pierścieniowaty']
# ['widoczny' 'też']
# ['plamka' 'rodzaj']
# ['nosowo' 'góra']
# ['nieregularny' 'kaliber']
# ['angiograficzny' 'widoczny']
# ['plamka' 'nieproliferacyjny']
# ['zmiana' 'ostrość']
# ['hiperfluorescencja' 'dolny']
# ['zlokalizować' 'dołek']
# ['pod' 'kontrola']
# ['drobne' 'punkt']
# ['bez' 'zmiana']
# ['af' 'może']
# ['naczyniówkowy' 'wynikać']
# ['neowaskularyzacja' 'faza']
# ['odpowiadać' 'klasyczny']
# ['oct' 'podjąć']
# ['widoczny' 'niewielki']
# ['dołowić' 'dołek']
# ['badana' 'obszar']
# ['mikroaneuryzmaty' 'hipofluorescencja']
# ['istotny' 'uniesienie']
# ['co' 'miesiąc']
# ['daleki' 'monitorować']
# ['soct' 'obraz']
# ['hiperfluorescencjanasilać' 'koniec']
# ['laseroterapia' 'wynik']
